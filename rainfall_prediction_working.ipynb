# %% [markdown]
# <a href="https://colab.research.google.com/github/Shibil-Basith/javalab/blob/main/rainfall_prediction_working.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import requests
import pandas as pd

# Define the API URL
url = "https://archive-api.open-meteo.com/v1/archive"

# Define request parameters
params = {
    "latitude": 10.8505,  # Kerala Latitude
    "longitude": 76.2711,  # Kerala Longitude
    "start_date": "1980-01-01",
    "end_date": "2024-12-31",
    "daily": [
        "temperature_2m_max",
        "temperature_2m_min",
        "precipitation_sum",
        "relative_humidity_2m_mean",  # ✅ Fixed humidity variable
        "wind_speed_10m_max",
        "surface_pressure_mean",  # ✅ Fixed pressure variable
        "cloud_cover_mean",
        "dew_point_2m_mean"
    ],
    "timezone": "Asia/Kolkata",
}


# Make API request
response = requests.get(url, params=params)
data = response.json()

# Check if the response contains 'daily' data
if "daily" in data:
    df = pd.DataFrame(data["daily"])
    df.to_csv("kerala_weather_data.csv", index=False)  # Save to CSV
    print(df.head())  # Display first few rows
else:
    print("Error fetching data:", data)  # Print error message
# Out:
#          time  temperature_2m_max  temperature_2m_min  precipitation_sum  \
# 0  1980-01-01                32.9                20.0                0.0
# 1  1980-01-02                32.9                19.1                0.0
# 2  1980-01-03                32.3                19.4                0.0
# 3  1980-01-04                32.5                19.8                0.0
# 4  1980-01-05                33.2                20.7                0.0
#
#    relative_humidity_2m_mean  wind_speed_10m_max  surface_pressure_mean  \
# 0                         67                 5.7                 1003.3
# 1                         62                12.8                 1003.1
# 2                         67                12.5                 1003.6
# 3                         66                11.0                 1003.2
# 4                         54                16.8                 1003.6
#
#    cloud_cover_mean  dew_point_2m_mean
# 0                25               18.8
# 1                78               17.1
# 2                 8               18.5
# 3                54               18.4
# 4                29               15.7

# %%
print(df.info())  # Shows column names, data types, and missing values
print(df.head())  # Displays the first 5 rows
print(df.describe())  # Shows summary statistics
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16437 entries, 0 to 16436
# Data columns (total 9 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   time                       16437 non-null  object
#  1   temperature_2m_max         16437 non-null  float64
#  2   temperature_2m_min         16437 non-null  float64
#  3   precipitation_sum          16437 non-null  float64
#  4   relative_humidity_2m_mean  16437 non-null  int64
#  5   wind_speed_10m_max         16437 non-null  float64
#  6   surface_pressure_mean      16437 non-null  float64
#  7   cloud_cover_mean           16437 non-null  int64
#  8   dew_point_2m_mean          16437 non-null  float64
# dtypes: float64(6), int64(2), object(1)
# memory usage: 1.1+ MB
# None
#          time  temperature_2m_max  temperature_2m_min  precipitation_sum  \
# 0  1980-01-01                32.9                20.0                0.0
# 1  1980-01-02                32.9                19.1                0.0
# 2  1980-01-03                32.3                19.4                0.0
# 3  1980-01-04                32.5                19.8                0.0
# 4  1980-01-05                33.2                20.7                0.0
#
#    relative_humidity_2m_mean  wind_speed_10m_max  surface_pressure_mean  \
# 0                         67                 5.7                 1003.3
# 1                         62                12.8                 1003.1
# 2                         67                12.5                 1003.6
# 3                         66                11.0                 1003.2
# 4                         54                16.8                 1003.6
#
#    cloud_cover_mean  dew_point_2m_mean
# 0                25               18.8
# 1                78               17.1
# 2                 8               18.5
# 3                54               18.4
# 4                29               15.7
#        temperature_2m_max  temperature_2m_min  precipitation_sum  \
# count        16437.000000        16437.000000       16437.000000
# mean            30.808037           22.736126           6.292310
# std              3.250271            1.669932          10.045791
# min             23.000000           15.000000           0.000000
# 25%             28.400000           22.000000           0.000000
# 50%             30.300000           22.800000           1.800000
# 75%             33.100000           23.700000           8.800000
# max             43.000000           28.200000         122.800000
#
#        relative_humidity_2m_mean  wind_speed_10m_max  surface_pressure_mean  \
# count               16437.000000        16437.000000           16437.000000
# mean                   78.078421           14.190966            1002.676182
# std                    13.455510            3.709652               1.709913
# min                    26.000000            3.400000             994.700000
# 25%                    67.000000           11.700000            1001.500000
# 50%                    83.000000           14.200000            1002.700000
# 75%                    89.000000           16.600000            1003.900000
# max                    98.000000           30.800000            1008.400000
#
#        cloud_cover_mean  dew_point_2m_mean
# count      16437.000000       16437.000000
# mean          66.839204          21.379072
# std           31.904377           2.735014
# min            0.000000           5.800000
# 25%           41.000000          20.400000
# 50%           77.000000          22.400000
# 75%           96.000000          23.100000
# max          100.000000          26.100000

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import shap
import tensorflow as tf
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Bidirectional, Dense, Dropout

# Load Dataset
df = pd.read_csv("kerala_weather_data.csv")
df['time'] = pd.to_datetime(df['time'])  # Convert time column
df.set_index('time', inplace=True)  # Set time as index

# Handle missing values
df.fillna(method='ffill', inplace=True)

# Define Features & Target
features = df.drop(columns=['precipitation_sum'])  # Remove target column
target = df['precipitation_sum']  # Rainfall prediction

# Normalize Features
scaler = MinMaxScaler()
features_scaled = scaler.fit_transform(features)

# Split Data into Train & Test
X_train, X_test, y_train, y_test = train_test_split(features_scaled, target, test_size=0.2, shuffle=False)

# Reshape for LSTM Input
X_train = np.reshape(X_train, (X_train.shape[0], X_train.shape[1], 1))
X_test = np.reshape(X_test, (X_test.shape[0], X_test.shape[1], 1))

# Build BiLSTM Model
model = Sequential([
    Bidirectional(LSTM(64, return_sequences=True), input_shape=(X_train.shape[1], 1)),
    Dropout(0.2),
    Bidirectional(LSTM(32, return_sequences=False)),
    Dense(16, activation='relu'),
    Dense(1)
])

model.compile(optimizer='adam', loss='mse')

# Train Model
history = model.fit(X_train, y_train, epochs=50, batch_size=16, validation_data=(X_test, y_test))

# Predictions
y_pred = model.predict(X_test)

# Evaluate Model
rmse = np.sqrt(mean_squared_error(y_test, y_pred))
mse = mean_squared_error(y_test, y_pred)
mae = mean_absolute_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)

print(f"RMSE: {rmse:.4f}")
print(f"MSE: {mse:.4f}")
print(f"MAE: {mae:.4f}")
print(f"R² Score: {r2:.4f}")

# SHAP Explainability
explainer = shap.Explainer(model, X_train)
shap_values = explainer(X_test[:100])

# SHAP Summary Plot
shap.summary_plot(shap_values, features.iloc[:100])

# Plot Predictions
plt.figure(figsize=(10, 5))
plt.plot(y_test.values, label="Actual")
plt.plot(y_pred, label="Predicted")
plt.legend()
plt.title("Rainfall Prediction using BiLSTM")
plt.show()
# Out:
# Epoch 1/50
# <ipython-input-25-e42948c15735>:19: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df.fillna(method='ffill', inplace=True)
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/rnn/bidirectional.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 822/822 ━━━━━━━━━━━━━━━━━━━━ 26s 21ms/step - loss: 68.7358 - val_loss: 107.2612
# Epoch 2/50
# 822/822 ━━━━━━━━━━━━━━━━━━━━ 19s 20ms/step - loss: 41.6675 - val_loss: 90.6273
# Epoch 3/50
# 822/822 ━━━━━━━━━━━━━━━━━━━━ 16s 20ms/step - loss: 38.6672 - val_loss: 86.3229
# Epoch 4/50
# 822/822 ━━━━━━━━━━━━━━━━━━━━ 21s 20ms/step - loss: 35.9954 - val_loss: 95.7832
# Epoch 5/50
# 822/822 ━━━━━━━━━━━━━━━━━━━━ 20s 20ms/step - loss: 33.7626 - val_loss: 87.4482
# Epoch 6/50
# 822/822 ━━━━━━━━━━━━━━━━━━━━ 20s 19ms/step - loss: 32.6223 - val_loss: 84.4182
# Epoch 7/50
# 822/822 ━━━━━━━━━━━━━━━━━━━━ 21s 20ms/step - loss: 29.0521 - val_loss: 82.1283
# Epoch 8/50
# 822/822 ━━━━━━━━━━━━━━━━━━━━ 20s 19ms/step - loss: 32.5131 - val_loss: 113.1437
# Epoch 9/50
# 822/822 ━━━━━━━━━━━━━━━━━━━━ 20s 19ms/step - loss: 29.9639 - val_loss: 95.1539
# Epoch 10/50
# 822/822 ━━━━━━━━━━━━━━━━━━━━ 17s 20ms/step - loss: 28.8063 - val_loss: 82.8371
# Epoch 11/50
# 822/822 ━━━━━━━━━━━━━━━━━━━━ 20s 19ms/step - loss: 27.8505 - val_loss: 85.0852
# Epoch 12/50
# 822/822 ━━━━━━━━━━━━━━━━━━━━ 20s 19ms/step - loss: 30.5396 - val_loss: 97.9035
# Epoch 13/50
# 822/822 ━━━━━━━━━━━━━━━━━━━━ 21s 19ms/step - loss: 27.9314 - val_loss: 99.2747
# Epoch 14/50
# 822/822 ━━━━━━━━━━━━━━━━━━━━ 20s 19ms/step - loss: 30.3150 - val_loss: 88.9694
# Epoch 15/50
# 822/822 ━━━━━━━━━━━━━━━━━━━━ 21s 19ms/step - loss: 30.5227 - val_loss: 98.9186
# Epoch 16/50
# 822/822 ━━━━━━━━━━━━━━━━━━━━ 21s 20ms/step - loss: 28.0379 - val_loss: 80.3990
# Epoch 17/50
# 822/822 ━━━━━━━━━━━━━━━━━━━━ 16s 19ms/step - loss: 28.8668 - val_loss: 87.8713
# Epoch 18/50
# 822/822 ━━━━━━━━━━━━━━━━━━━━ 20s 19ms/step - loss: 26.4642 - val_loss: 76.7139
# Epoch 19/50
# 822/822 ━━━━━━━━━━━━━━━━━━━━ 16s 19ms/step - loss: 29.8838 - val_loss: 97.2916
# Epoch 20/50
# 822/822 ━━━━━━━━━━━━━━━━━━━━ 20s 19ms/step - loss: 28.8510 - val_loss: 84.8068
# Epoch 21/50
# 822/822 ━━━━━━━━━━━━━━━━━━━━ 15s 19ms/step - loss: 26.4061 - val_loss: 70.9061
# Epoch 22/50
# 822/822 ━━━━━━━━━━━━━━━━━━━━ 20s 18ms/step - loss: 25.5110 - val_loss: 74.1259
# Epoch 23/50
# 822/822 ━━━━━━━━━━━━━━━━━━━━ 17s 21ms/step - loss: 28.1330 - val_loss: 80.9908
# Epoch 24/50
# 822/822 ━━━━━━━━━━━━━━━━━━━━ 16s 19ms/step - loss: 29.1729 - val_loss: 91.6660
# Epoch 25/50
# 822/822 ━━━━━━━━━━━━━━━━━━━━ 16s 19ms/step - loss: 26.5205 - val_loss: 79.9667
# Epoch 26/50
# 822/822 ━━━━━━━━━━━━━━━━━━━━ 20s 19ms/step - loss: 24.4684 - val_loss: 83.6385
# Epoch 27/50
# 822/822 ━━━━━━━━━━━━━━━━━━━━ 15s 18ms/step - loss: 26.6445 - val_loss: 84.6930
# Epoch 28/50
# 822/822 ━━━━━━━━━━━━━━━━━━━━ 21s 19ms/step - loss: 24.3092 - val_loss: 73.3420
# Epoch 29/50
# 822/822 ━━━━━━━━━━━━━━━━━━━━ 15s 18ms/step - loss: 24.4600 - val_loss: 78.4285
# Epoch 30/50
# 822/822 ━━━━━━━━━━━━━━━━━━━━ 21s 19ms/step - loss: 24.5546 - val_loss: 69.0989
# Epoch 31/50
# 822/822 ━━━━━━━━━━━━━━━━━━━━ 20s 18ms/step - loss: 23.6635 - val_loss: 73.6119
# Epoch 32/50
# 822/822 ━━━━━━━━━━━━━━━━━━━━ 15s 19ms/step - loss: 22.9630 - val_loss: 72.1850
# Epoch 33/50
# 822/822 ━━━━━━━━━━━━━━━━━━━━ 20s 18ms/step - loss: 24.3342 - val_loss: 79.8128
# Epoch 34/50
# 822/822 ━━━━━━━━━━━━━━━━━━━━ 15s 18ms/step - loss: 22.8018 - val_loss: 74.8211
# Epoch 35/50
# 822/822 ━━━━━━━━━━━━━━━━━━━━ 21s 19ms/step - loss: 23.6575 - val_loss: 71.3453
# Epoch 36/50
# 822/822 ━━━━━━━━━━━━━━━━━━━━ 16s 19ms/step - loss: 26.1214 - val_loss: 76.7604
# Epoch 37/50
# 822/822 ━━━━━━━━━━━━━━━━━━━━ 20s 18ms/step - loss: 22.8274 - val_loss: 62.5505
# Epoch 38/50
# 822/822 ━━━━━━━━━━━━━━━━━━━━ 17s 20ms/step - loss: 22.6061 - val_loss: 85.1787
# Epoch 39/50
# 822/822 ━━━━━━━━━━━━━━━━━━━━ 19s 19ms/step - loss: 22.6651 - val_loss: 69.1090
# Epoch 40/50
# 822/822 ━━━━━━━━━━━━━━━━━━━━ 16s 19ms/step - loss: 24.6304 - val_loss: 81.4407
# Epoch 41/50
# 822/822 ━━━━━━━━━━━━━━━━━━━━ 20s 19ms/step - loss: 23.8236 - val_loss: 62.4220
# Epoch 42/50
# 822/822 ━━━━━━━━━━━━━━━━━━━━ 21s 19ms/step - loss: 23.6647 - val_loss: 62.6325
# Epoch 43/50
# 822/822 ━━━━━━━━━━━━━━━━━━━━ 20s 18ms/step - loss: 23.3126 - val_loss: 68.2648
# Epoch 44/50
# 822/822 ━━━━━━━━━━━━━━━━━━━━ 21s 19ms/step - loss: 22.8969 - val_loss: 67.4640
# Epoch 45/50
# 822/822 ━━━━━━━━━━━━━━━━━━━━ 21s 19ms/step - loss: 24.0296 - val_loss: 73.3182
# Epoch 46/50
# 822/822 ━━━━━━━━━━━━━━━━━━━━ 15s 18ms/step - loss: 21.7606 - val_loss: 60.3610
# Epoch 47/50
# 822/822 ━━━━━━━━━━━━━━━━━━━━ 20s 18ms/step - loss: 21.2546 - val_loss: 62.1602
# Epoch 48/50
# 822/822 ━━━━━━━━━━━━━━━━━━━━ 15s 18ms/step - loss: 22.1033 - val_loss: 61.5217
# Epoch 49/50
# 822/822 ━━━━━━━━━━━━━━━━━━━━ 20s 18ms/step - loss: 21.7664 - val_loss: 77.5655
# Epoch 50/50
# 822/822 ━━━━━━━━━━━━━━━━━━━━ 15s 19ms/step - loss: 23.3996 - val_loss: 62.8128
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step
# RMSE: 7.9255
# MSE: 62.8128
# MAE: 4.0798
# R² Score: 0.6009
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-25-e42948c15735> in <cell line: 0>()
#      64 # SHAP Explainability
#      65 explainer = shap.Explainer(model, X_train)
# ---> 66 shap_values = explainer(X_test[:100])
#      67
#      68 # SHAP Summary Plot
#
# /usr/local/lib/python3.11/dist-packages/shap/explainers/_permutation.py in __call__(self, max_evals, main_effects, error_bounds, batch_size, outputs, silent, *args)
#      75                  outputs=None, silent=False):
#      76         """Explain the output of the model on the given arguments."""
# ---> 77         return super().__call__(
#      78             *args, max_evals=max_evals, main_effects=main_effects, error_bounds=error_bounds, batch_size=batch_size,
#      79             outputs=outputs, silent=silent
#
# /usr/local/lib/python3.11/dist-packages/shap/explainers/_explainer.py in __call__(self, max_evals, main_effects, error_bounds, batch_size, outputs, silent, *args, **kwargs)
#     264             feature_names = [[] for _ in range(len(args))]
#     265         for row_args in show_progress(zip(*args), num_rows, self.__class__.__name__+" explainer", silent):
# --> 266             row_result = self.explain_row(
#     267                 *row_args, max_evals=max_evals, main_effects=main_effects, error_bounds=error_bounds,
#     268                 batch_size=batch_size, outputs=outputs, silent=silent, **kwargs
#
# /usr/local/lib/python3.11/dist-packages/shap/explainers/_permutation.py in explain_row(self, max_evals, main_effects, error_bounds, batch_size, outputs, silent, *row_args)
#     131
#     132                 # evaluate the masked model
# --> 133                 outputs = fm(masks, zero_index=0, batch_size=batch_size)
#     134
#     135                 if row_values is None:
#
# /usr/local/lib/python3.11/dist-packages/shap/utils/_masked_model.py in __call__(self, masks, zero_index, batch_size)
#      65                 full_masks = np.zeros((int(np.sum(masks >= 0)), self._masker_cols), dtype=bool)
#      66                 _convert_delta_mask_to_full(masks, full_masks)
# ---> 67                 return self._full_masking_call(full_masks, zero_index=zero_index, batch_size=batch_size)
#      68
#      69         else:
#
# /usr/local/lib/python3.11/dist-packages/shap/utils/_masked_model.py in _full_masking_call(self, masks, zero_index, batch_size)
#      94                     masked_inputs = self.masker(delta_ind, *self.args).copy()
#      95                 else:
# ---> 96                     masked_inputs = self.masker(mask, *self.args)
#      97
#      98                 # get a copy that won't get overwritten by the next iteration
#
# TypeError: 'numpy.ndarray' object is not callable

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import shap
import tensorflow as tf
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Bidirectional, Dense, Dropout, GRU

# Load Dataset
df = pd.read_csv("kerala_weather_data.csv")
df['time'] = pd.to_datetime(df['time'])  # Convert time column
df.set_index('time', inplace=True)  # Set time as index

# Handle Missing Values
df.fillna(method='ffill', inplace=True)

# Feature Engineering
# Add lag features
for lag in range(1, 8):
    df[f'lag_{lag}'] = df['precipitation_sum'].shift(lag)

# Add rolling features
df['rolling_mean_3'] = df['precipitation_sum'].rolling(window=3).mean()
df['rolling_std_3'] = df['precipitation_sum'].rolling(window=3).std()
df['rolling_mean_7'] = df['precipitation_sum'].rolling(window=7).mean()

# Add seasonal features
df['month'] = df.index.month
df['day_of_year'] = df.index.day_of_year
df['hour'] = df.index.hour

# Drop rows with NaN after lagging
df.dropna(inplace=True)

# Define Features and Target
features = df.drop(columns=['precipitation_sum'])
target = df['precipitation_sum']

# Normalize Features
scaler = MinMaxScaler()
features_scaled = scaler.fit_transform(features)

# Split Data into Train & Test
X_train, X_test, y_train, y_test = train_test_split(features_scaled, target, test_size=0.2, shuffle=False)

# Reshape for LSTM Input
X_train = np.reshape(X_train, (X_train.shape[0], X_train.shape[1], 1))
X_test = np.reshape(X_test, (X_test.shape[0], X_test.shape[1], 1))

# Build GRU-LSTM Hybrid Model
model = Sequential([
    Bidirectional(LSTM(128, return_sequences=True), input_shape=(X_train.shape[1], 1)),
    Dropout(0.3),
    Bidirectional(GRU(64, return_sequences=True)),
    Dropout(0.3),
    Bidirectional(LSTM(32, return_sequences=False)),
    Dense(16, activation='relu'),
    Dense(1)
])

model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=0.001), loss='mse')

# Train Model
history = model.fit(X_train, y_train, epochs=100, batch_size=32, validation_data=(X_test, y_test),
                    callbacks=[
                        tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True),
                        tf.keras.callbacks.ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=5)
                    ])

# Predictions
y_pred = model.predict(X_test)

# Evaluate Model
rmse = np.sqrt(mean_squared_error(y_test, y_pred))
mse = mean_squared_error(y_test, y_pred)
mae = mean_absolute_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)

print(f"RMSE: {rmse:.4f}")
print(f"MSE: {mse:.4f}")
print(f"MAE: {mae:.4f}")
print(f"R² Score: {r2:.4f}")
# Out:
# <ipython-input-6-79d32e6215a1>:19: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df.fillna(method='ffill', inplace=True)
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/rnn/bidirectional.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Epoch 1/100
# 411/411 ━━━━━━━━━━━━━━━━━━━━ 60s 113ms/step - loss: 67.7916 - val_loss: 92.7700 - learning_rate: 0.0010
# Epoch 2/100
# 411/411 ━━━━━━━━━━━━━━━━━━━━ 46s 112ms/step - loss: 48.8438 - val_loss: 93.8191 - learning_rate: 0.0010
# Epoch 3/100
# 411/411 ━━━━━━━━━━━━━━━━━━━━ 83s 115ms/step - loss: 48.4987 - val_loss: 90.8250 - learning_rate: 0.0010
# Epoch 4/100
# 411/411 ━━━━━━━━━━━━━━━━━━━━ 46s 112ms/step - loss: 39.6668 - val_loss: 70.9190 - learning_rate: 0.0010
# Epoch 5/100
# 411/411 ━━━━━━━━━━━━━━━━━━━━ 82s 112ms/step - loss: 26.4156 - val_loss: 56.8039 - learning_rate: 0.0010
# Epoch 6/100
# 411/411 ━━━━━━━━━━━━━━━━━━━━ 85s 120ms/step - loss: 24.9902 - val_loss: 58.6650 - learning_rate: 0.0010
# Epoch 7/100
# 411/411 ━━━━━━━━━━━━━━━━━━━━ 80s 116ms/step - loss: 21.9724 - val_loss: 59.7751 - learning_rate: 0.0010
# Epoch 8/100
# 411/411 ━━━━━━━━━━━━━━━━━━━━ 82s 116ms/step - loss: 22.1673 - val_loss: 49.3923 - learning_rate: 0.0010
# Epoch 9/100
# 411/411 ━━━━━━━━━━━━━━━━━━━━ 81s 114ms/step - loss: 20.2315 - val_loss: 55.8399 - learning_rate: 0.0010
# Epoch 10/100
# 411/411 ━━━━━━━━━━━━━━━━━━━━ 81s 111ms/step - loss: 19.0966 - val_loss: 44.2995 - learning_rate: 0.0010
# Epoch 11/100
# 411/411 ━━━━━━━━━━━━━━━━━━━━ 82s 112ms/step - loss: 19.2513 - val_loss: 40.7971 - learning_rate: 0.0010
# Epoch 12/100
# 411/411 ━━━━━━━━━━━━━━━━━━━━ 81s 111ms/step - loss: 17.7909 - val_loss: 44.3264 - learning_rate: 0.0010
# Epoch 13/100
# 411/411 ━━━━━━━━━━━━━━━━━━━━ 48s 116ms/step - loss: 18.4783 - val_loss: 41.9417 - learning_rate: 0.0010
# Epoch 14/100
# 411/411 ━━━━━━━━━━━━━━━━━━━━ 82s 116ms/step - loss: 17.7492 - val_loss: 36.6776 - learning_rate: 0.0010
# Epoch 15/100
# 411/411 ━━━━━━━━━━━━━━━━━━━━ 81s 115ms/step - loss: 16.7226 - val_loss: 38.5720 - learning_rate: 0.0010
# Epoch 16/100
# 411/411 ━━━━━━━━━━━━━━━━━━━━ 80s 111ms/step - loss: 15.4841 - val_loss: 37.7946 - learning_rate: 0.0010
# Epoch 17/100
# 411/411 ━━━━━━━━━━━━━━━━━━━━ 46s 112ms/step - loss: 15.0841 - val_loss: 34.7034 - learning_rate: 0.0010
# Epoch 18/100
# 411/411 ━━━━━━━━━━━━━━━━━━━━ 83s 114ms/step - loss: 13.0944 - val_loss: 36.8735 - learning_rate: 0.0010
# Epoch 19/100
# 411/411 ━━━━━━━━━━━━━━━━━━━━ 83s 117ms/step - loss: 13.0649 - val_loss: 37.4452 - learning_rate: 0.0010
# Epoch 20/100
# 411/411 ━━━━━━━━━━━━━━━━━━━━ 46s 113ms/step - loss: 12.2617 - val_loss: 37.1901 - learning_rate: 0.0010
# Epoch 21/100
# 411/411 ━━━━━━━━━━━━━━━━━━━━ 82s 114ms/step - loss: 10.6377 - val_loss: 35.5613 - learning_rate: 0.0010
# Epoch 22/100
# 411/411 ━━━━━━━━━━━━━━━━━━━━ 48s 117ms/step - loss: 11.2103 - val_loss: 28.9313 - learning_rate: 0.0010
# Epoch 23/100
# 411/411 ━━━━━━━━━━━━━━━━━━━━ 82s 117ms/step - loss: 10.9345 - val_loss: 29.4556 - learning_rate: 0.0010
# Epoch 24/100
# 411/411 ━━━━━━━━━━━━━━━━━━━━ 82s 117ms/step - loss: 11.2284 - val_loss: 24.7563 - learning_rate: 0.0010
# Epoch 25/100
# 411/411 ━━━━━━━━━━━━━━━━━━━━ 84s 122ms/step - loss: 9.7882 - val_loss: 37.7681 - learning_rate: 0.0010
# Epoch 26/100
# 411/411 ━━━━━━━━━━━━━━━━━━━━ 79s 114ms/step - loss: 10.2397 - val_loss: 24.5517 - learning_rate: 0.0010
# Epoch 27/100
# 411/411 ━━━━━━━━━━━━━━━━━━━━ 45s 110ms/step - loss: 11.2590 - val_loss: 34.2798 - learning_rate: 0.0010
# Epoch 28/100
# 411/411 ━━━━━━━━━━━━━━━━━━━━ 82s 110ms/step - loss: 12.1988 - val_loss: 23.2295 - learning_rate: 0.0010
# Epoch 29/100
# 411/411 ━━━━━━━━━━━━━━━━━━━━ 86s 121ms/step - loss: 9.1368 - val_loss: 22.6495 - learning_rate: 0.0010
# Epoch 30/100
# 411/411 ━━━━━━━━━━━━━━━━━━━━ 46s 111ms/step - loss: 7.9658 - val_loss: 17.1401 - learning_rate: 0.0010
# Epoch 31/100
# 411/411 ━━━━━━━━━━━━━━━━━━━━ 82s 111ms/step - loss: 6.3770 - val_loss: 14.0929 - learning_rate: 0.0010
# Epoch 32/100
# 411/411 ━━━━━━━━━━━━━━━━━━━━ 46s 111ms/step - loss: 5.8815 - val_loss: 14.5399 - learning_rate: 0.0010
# Epoch 33/100
# 411/411 ━━━━━━━━━━━━━━━━━━━━ 83s 115ms/step - loss: 4.4510 - val_loss: 11.1845 - learning_rate: 0.0010
# Epoch 34/100
# 411/411 ━━━━━━━━━━━━━━━━━━━━ 80s 110ms/step - loss: 5.2593 - val_loss: 12.1339 - learning_rate: 0.0010
# Epoch 35/100
# 411/411 ━━━━━━━━━━━━━━━━━━━━ 46s 111ms/step - loss: 3.7466 - val_loss: 14.8177 - learning_rate: 0.0010
# Epoch 36/100
# 411/411 ━━━━━━━━━━━━━━━━━━━━ 45s 110ms/step - loss: 3.5004 - val_loss: 9.6890 - learning_rate: 0.0010
# Epoch 37/100
# 411/411 ━━━━━━━━━━━━━━━━━━━━ 48s 117ms/step - loss: 3.2289 - val_loss: 9.4400 - learning_rate: 0.0010
# Epoch 38/100
# 411/411 ━━━━━━━━━━━━━━━━━━━━ 84s 121ms/step - loss: 2.9954 - val_loss: 7.9979 - learning_rate: 0.0010
# Epoch 39/100
# 411/411 ━━━━━━━━━━━━━━━━━━━━ 79s 113ms/step - loss: 2.5365 - val_loss: 9.8501 - learning_rate: 0.0010
# Epoch 40/100
# 411/411 ━━━━━━━━━━━━━━━━━━━━ 81s 111ms/step - loss: 3.0104 - val_loss: 13.6074 - learning_rate: 0.0010
# Epoch 41/100
# 411/411 ━━━━━━━━━━━━━━━━━━━━ 82s 111ms/step - loss: 2.2337 - val_loss: 12.8326 - learning_rate: 0.0010
# Epoch 42/100
# 411/411 ━━━━━━━━━━━━━━━━━━━━ 82s 112ms/step - loss: 2.5762 - val_loss: 8.0839 - learning_rate: 0.0010
# Epoch 43/100
# 411/411 ━━━━━━━━━━━━━━━━━━━━ 83s 115ms/step - loss: 1.8931 - val_loss: 7.5745 - learning_rate: 0.0010
# Epoch 44/100
# 411/411 ━━━━━━━━━━━━━━━━━━━━ 81s 112ms/step - loss: 1.9048 - val_loss: 7.4020 - learning_rate: 0.0010
# Epoch 45/100
# 411/411 ━━━━━━━━━━━━━━━━━━━━ 45s 109ms/step - loss: 2.2020 - val_loss: 10.8366 - learning_rate: 0.0010
# Epoch 46/100
# 411/411 ━━━━━━━━━━━━━━━━━━━━ 83s 111ms/step - loss: 1.7185 - val_loss: 8.9223 - learning_rate: 0.0010
# Epoch 47/100
# 411/411 ━━━━━━━━━━━━━━━━━━━━ 83s 115ms/step - loss: 1.5024 - val_loss: 9.5926 - learning_rate: 0.0010
# Epoch 48/100
# 411/411 ━━━━━━━━━━━━━━━━━━━━ 81s 113ms/step - loss: 1.6795 - val_loss: 6.1489 - learning_rate: 0.0010
# Epoch 49/100
# 411/411 ━━━━━━━━━━━━━━━━━━━━ 83s 117ms/step - loss: 1.2316 - val_loss: 7.4474 - learning_rate: 0.0010
# Epoch 50/100
# 411/411 ━━━━━━━━━━━━━━━━━━━━ 46s 111ms/step - loss: 1.2752 - val_loss: 7.2315 - learning_rate: 0.0010
# Epoch 51/100
# 411/411 ━━━━━━━━━━━━━━━━━━━━ 83s 113ms/step - loss: 1.5934 - val_loss: 7.3396 - learning_rate: 0.0010
# Epoch 52/100
# 411/411 ━━━━━━━━━━━━━━━━━━━━ 82s 114ms/step - loss: 1.0391 - val_loss: 6.2103 - learning_rate: 0.0010
# Epoch 53/100
# 411/411 ━━━━━━━━━━━━━━━━━━━━ 82s 114ms/step - loss: 1.0631 - val_loss: 6.2586 - learning_rate: 0.0010
# Epoch 54/100
# 411/411 ━━━━━━━━━━━━━━━━━━━━ 81s 111ms/step - loss: 0.7530 - val_loss: 4.6059 - learning_rate: 5.0000e-04
# Epoch 55/100
# 411/411 ━━━━━━━━━━━━━━━━━━━━ 46s 111ms/step - loss: 0.5740 - val_loss: 4.8481 - learning_rate: 5.0000e-04
# Epoch 56/100
# 411/411 ━━━━━━━━━━━━━━━━━━━━ 84s 115ms/step - loss: 0.5285 - val_loss: 3.8016 - learning_rate: 5.0000e-04
# Epoch 57/100
# 411/411 ━━━━━━━━━━━━━━━━━━━━ 82s 116ms/step - loss: 0.6120 - val_loss: 4.1792 - learning_rate: 5.0000e-04
# Epoch 58/100
# 411/411 ━━━━━━━━━━━━━━━━━━━━ 45s 110ms/step - loss: 0.5356 - val_loss: 5.7537 - learning_rate: 5.0000e-04
# Epoch 59/100
# 411/411 ━━━━━━━━━━━━━━━━━━━━ 82s 111ms/step - loss: 0.6340 - val_loss: 6.7056 - learning_rate: 5.0000e-04
# Epoch 60/100
# 411/411 ━━━━━━━━━━━━━━━━━━━━ 46s 111ms/step - loss: 0.6518 - val_loss: 5.9441 - learning_rate: 5.0000e-04
# Epoch 61/100
# 411/411 ━━━━━━━━━━━━━━━━━━━━ 86s 121ms/step - loss: 0.4741 - val_loss: 5.1357 - learning_rate: 5.0000e-04
# Epoch 62/100
# 411/411 ━━━━━━━━━━━━━━━━━━━━ 45s 110ms/step - loss: 0.4043 - val_loss: 6.1528 - learning_rate: 2.5000e-04
# Epoch 63/100
# 411/411 ━━━━━━━━━━━━━━━━━━━━ 82s 112ms/step - loss: 0.3535 - val_loss: 5.4715 - learning_rate: 2.5000e-04
# Epoch 64/100
# 411/411 ━━━━━━━━━━━━━━━━━━━━ 84s 116ms/step - loss: 0.3644 - val_loss: 5.0040 - learning_rate: 2.5000e-04
# Epoch 65/100
# 411/411 ━━━━━━━━━━━━━━━━━━━━ 48s 116ms/step - loss: 0.4010 - val_loss: 4.2946 - learning_rate: 2.5000e-04
# Epoch 66/100
# 411/411 ━━━━━━━━━━━━━━━━━━━━ 45s 110ms/step - loss: 0.2949 - val_loss: 4.3547 - learning_rate: 2.5000e-04
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 7s 51ms/step
# RMSE: 1.9498
# MSE: 3.8016
# MAE: 0.6121
# R² Score: 0.9759
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-6-79d32e6215a1> in <cell line: 0>()
#      88 # SHAP Explainability
#      89 explainer = shap.Explainer(model, X_train)
# ---> 90 shap_values = explainer(X_test[:100])
#      91
#      92 # SHAP Summary Plot
#
# /usr/local/lib/python3.11/dist-packages/shap/explainers/_permutation.py in __call__(self, max_evals, main_effects, error_bounds, batch_size, outputs, silent, *args)
#      75                  outputs=None, silent=False):
#      76         """Explain the output of the model on the given arguments."""
# ---> 77         return super().__call__(
#      78             *args, max_evals=max_evals, main_effects=main_effects, error_bounds=error_bounds, batch_size=batch_size,
#      79             outputs=outputs, silent=silent
#
# /usr/local/lib/python3.11/dist-packages/shap/explainers/_explainer.py in __call__(self, max_evals, main_effects, error_bounds, batch_size, outputs, silent, *args, **kwargs)
#     264             feature_names = [[] for _ in range(len(args))]
#     265         for row_args in show_progress(zip(*args), num_rows, self.__class__.__name__+" explainer", silent):
# --> 266             row_result = self.explain_row(
#     267                 *row_args, max_evals=max_evals, main_effects=main_effects, error_bounds=error_bounds,
#     268                 batch_size=batch_size, outputs=outputs, silent=silent, **kwargs
#
# /usr/local/lib/python3.11/dist-packages/shap/explainers/_permutation.py in explain_row(self, max_evals, main_effects, error_bounds, batch_size, outputs, silent, *row_args)
#     131
#     132                 # evaluate the masked model
# --> 133                 outputs = fm(masks, zero_index=0, batch_size=batch_size)
#     134
#     135                 if row_values is None:
#
# /usr/local/lib/python3.11/dist-packages/shap/utils/_masked_model.py in __call__(self, masks, zero_index, batch_size)
#      65                 full_masks = np.zeros((int(np.sum(masks >= 0)), self._masker_cols), dtype=bool)
#      66                 _convert_delta_mask_to_full(masks, full_masks)
# ---> 67                 return self._full_masking_call(full_masks, zero_index=zero_index, batch_size=batch_size)
#      68
#      69         else:
#
# /usr/local/lib/python3.11/dist-packages/shap/utils/_masked_model.py in _full_masking_call(self, masks, zero_index, batch_size)
#      94                     masked_inputs = self.masker(delta_ind, *self.args).copy()
#      95                 else:
# ---> 96                     masked_inputs = self.masker(mask, *self.args)
#      97
#      98                 # get a copy that won't get overwritten by the next iteration
#
# TypeError: 'numpy.ndarray' object is not callable

# %%
model.save("rainfall_prediction_model.h5")
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.

# %%
# SHAP Explainability
X_train_summary = X_train[:100]
explainer = shap.DeepExplainer(model, X_train_summary)
shap_values = explainer.shap_values(X_test[:100])

# SHAP Summary Plot
shap.summary_plot(shap_values[0], features.iloc[:100])

# Plot Predictions
plt.figure(figsize=(10, 5))
plt.plot(y_test.values, label="Actual")
plt.plot(y_pred, label="Predicted")
plt.legend()
plt.title("Rainfall Prediction using Hybrid GRU-LSTM")
plt.show()
# Out:
# /usr/local/lib/python3.11/dist-packages/shap/explainers/_deep/deep_tf.py:99: UserWarning: Your TensorFlow version is newer than 2.4.0 and so graph support has been removed in eager mode and some static graphs may not be supported. See PR #1483 for discussion.
#   warnings.warn("Your TensorFlow version is newer than 2.4.0 and so graph support has been removed in eager mode and some static graphs may not be supported. See PR #1483 for discussion.")
# ---------------------------------------------------------------------------
# StagingError                              Traceback (most recent call last)
# <ipython-input-8-2f477927e1c3> in <cell line: 0>()
#       2 X_train_summary = X_train[:100]
#       3 explainer = shap.DeepExplainer(model, X_train_summary)
# ----> 4 shap_values = explainer.shap_values(X_test[:100])
#       5
#       6 # SHAP Summary Plot
#
# /usr/local/lib/python3.11/dist-packages/shap/explainers/_deep/__init__.py in shap_values(self, X, ranked_outputs, output_rank_order, check_additivity)
#     157
#     158         """
# --> 159         return self.explainer.shap_values(X, ranked_outputs, output_rank_order, check_additivity=check_additivity)
#
# /usr/local/lib/python3.11/dist-packages/shap/explainers/_deep/deep_tf.py in shap_values(self, X, ranked_outputs, output_rank_order, check_additivity)
#     327                 # run attribution computation graph
#     328                 feature_ind = model_output_ranks[j,i]
# --> 329                 sample_phis = self.run(self.phi_symbolic(feature_ind), self.model_inputs, joint_input)
#     330
#     331                 # assign the attributions to the right part of the output arrays
#
# /usr/local/lib/python3.11/dist-packages/shap/explainers/_deep/deep_tf.py in run(self, out, model_inputs, X)
#     383
#     384                 return final_out
# --> 385             return self.execute_with_overridden_gradients(anon)
#     386
#     387     def custom_grad(self, op, *grads):
#
# /usr/local/lib/python3.11/dist-packages/shap/explainers/_deep/deep_tf.py in execute_with_overridden_gradients(self, f)
#     418         # define the computation graph for the attribution values using a custom gradient-like computation
#     419         try:
# --> 420             out = f()
#     421         finally:
#     422             # reinstate the backpropagatable check
#
# /usr/local/lib/python3.11/dist-packages/shap/explainers/_deep/deep_tf.py in anon()
#     376                     v = tf.constant(data, dtype=self.model_inputs[i].dtype)
#     377                     inputs.append(v)
# --> 378                 final_out = out(inputs)
#     379                 try:
#     380                     tf_execute.record_gradient = tf_backprop._record_gradient
#
# /usr/local/lib/python3.11/dist-packages/tensorflow/python/util/traceback_utils.py in error_handler(*args, **kwargs)
#     151     except Exception as e:
#     152       filtered_tb = _process_traceback_frames(e.__traceback__)
# --> 153       raise e.with_traceback(filtered_tb) from None
#     154     finally:
#     155       del filtered_tb
#
# /usr/local/lib/python3.11/dist-packages/tensorflow/python/eager/polymorphic_function/autograph_util.py in autograph_handler(*args, **kwargs)
#      50     except Exception as e:  # pylint:disable=broad-except
#      51       if hasattr(e, "ag_error_metadata"):
# ---> 52         raise e.ag_error_metadata.to_exception(e)
#      53       else:
#      54         raise
#
# StagingError: in user code:
#
#     File "/usr/local/lib/python3.11/dist-packages/shap/explainers/_deep/deep_tf.py", line 269, in grad_graph  *
#         x_grad = tape.gradient(out, shap_rAnD)
#
#     LookupError: gradient registry has no entry for: shap_TensorListStack
